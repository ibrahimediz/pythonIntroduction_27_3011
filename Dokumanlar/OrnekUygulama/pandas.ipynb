# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
with open("json_mock_data.json") as f:
    veri = json.load(f)
df = pd.DataFrame(data=veri)
df.head()
# Out:
#   insert_date update_date  id first_name   last_name  \
# 0  06.01.2023  26.02.2023   1      Tasha      Biford
# 1  04.12.2022  24.07.2023   2      Anson    Beaushaw
# 2  05.03.2023  18.01.2023   3     Paulie    Blancowe
# 3  24.01.2023  17.04.2023   4       Brig  Desborough
# 4  25.02.2023  08.02.2023   5       Inna      Sutter
#
#                            email      gender salary currency_code
# 0                 tbiford0@51.la      Female   7513           JPY
# 1       abeaushaw1@homestead.com        Male   4708           ARS
# 2         pblancowe2@typepad.com        Male   7455           HRK
# 3  bdesborough3@chronoengine.com        Male   2873           BRL
# 4              isutter4@ehow.com  Polygender   8640           IQD

# %%
df[df.salary>=5000]
# Out:
#     insert_date update_date   id first_name  last_name  \
# 0    06.01.2023  26.02.2023    1      Tasha     Biford
# 2    05.03.2023  18.01.2023    3     Paulie   Blancowe
# 4    25.02.2023  08.02.2023    5       Inna     Sutter
# 6    09.08.2023  16.11.2023    7      Stern  Levermore
# 8    15.02.2023  24.11.2023    9      Perla     Lembke
# ..          ...         ...  ...        ...        ...
# 991  07.03.2023  01.09.2023  992        Fay      Sille
# 992  09.02.2023  05.12.2022  993       Bree     McCall
# 993  17.05.2023  16.09.2023  994     Jaymee    Burkman
# 994  29.11.2023  19.05.2023  995    Giacopo    Samwyse
# 998  26.02.2023  12.11.2023  999      Ilene    Gilbert
#
#                          email      gender salary currency_code
# 0               tbiford0@51.la      Female   7513           JPY
# 2       pblancowe2@typepad.com        Male   7455           HRK
# 4            isutter4@ehow.com  Polygender   8640           IQD
# ...

# %%
df[df.salary>=5000].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>
